# %%
import numpy as np
import pandas as pd

# %%
job_postings = pd.read_csv('fake_job_postings.csv', index_col = 'job_id')

# %%
job_postings
# Out:
#                                                     title  \
# job_id
# 1                                        Marketing Intern
# 2               Customer Service - Cloud Video Production
# 3                 Commissioning Machinery Assistant (CMA)
# 4                       Account Executive - Washington DC
# 5                                     Bill Review Manager
# ...                                                   ...
# 17876                    Account Director - Distribution
# 17877                                  Payroll Accountant
# 17878   Project Cost Control Staff Engineer - Cost Con...
# 17879                                    Graphic Designer
# 17880                          Web Application Developers
#
#                     location   department salary_range  \
# job_id
# 1           US, NY, New York    Marketing          NaN
# 2             NZ, , Auckland      Success          NaN
# 3              US, IA, Wever          NaN          NaN
# ...

# %%
job_postings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17880 entries, 1 to 17880
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                17880 non-null  object
#  1   location             17534 non-null  object
#  2   department           6333 non-null   object
#  3   salary_range         2868 non-null   object
#  4   company_profile      14572 non-null  object
#  5   description          17879 non-null  object
#  6   requirements         15185 non-null  object
#  7   benefits             10670 non-null  object
#  8   telecommuting        17880 non-null  int64
#  9   has_company_logo     17880 non-null  int64
#  10  has_questions        17880 non-null  int64
#  11  employment_type      14409 non-null  object
#  12  required_experience  10830 non-null  object
#  13  required_education   9775 non-null   object
#  14  industry             12977 non-null  object
# ...

# %%
job_postings.describe()
# Out:
#        telecommuting  has_company_logo  has_questions    fraudulent
# count   17880.000000      17880.000000   17880.000000  17880.000000
# mean        0.042897          0.795302       0.491723      0.048434
# std         0.202631          0.403492       0.499945      0.214688
# min         0.000000          0.000000       0.000000      0.000000
# 25%         0.000000          1.000000       0.000000      0.000000
# 50%         0.000000          1.000000       0.000000      0.000000
# 75%         0.000000          1.000000       1.000000      0.000000
# max         1.000000          1.000000       1.000000      1.000000

# %%
#The meta deta with accurate description of what 0, 1 means could not be found on the github website, hence I interpreted zero and ones as follows
#0 - Non-Fraudulent
#1 - Fraudlent
job_postings['fraudulent'].value_counts()
# Out:
# 0    17014
# 1      866
# Name: fraudulent, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.bar(['Non Fraudulent Postings', 'Fraudulent Postings'], [17014, 866], color = ['blue', 'red'])
plt.title("Ratio of Non-Fraudulent Postings VS Fraudulent Postings")
plt.ylabel('Job Posting Count')
# Out:
# Text(0, 0.5, 'Job Posting Count')

# %%
#Fraudulent Job Postings 
fraudulent = job_postings[job_postings['fraudulent'] == 1]
fraudulent
# Out:
#                                              title  \
# job_id
# 99                                 IC&E Technician
# 145                                   Forward Cap.
# 174              Technician Instrument & Controls
# 181                                Sales Executive
# 216                        IC&E Technician Mt Poso
# ...                                            ...
# 17828   Student Positions Part-Time and Full-Time.
# 17829                              Sales Associate
# 17830                            Android Developer
# 17831                               Payroll Clerk
# 17832                              Furniture mover
#
#                                   location            department  \
# job_id
# 99                       US, , Stocton, CA          Oil & Energy
# 145                                    NaN                   NaN
# 174                                     US  Power Plant & Energy
# 181                        PK, SD, Karachi                 Sales
# ...

# %%
fraudulent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 866 entries, 99 to 17832
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                866 non-null    object
#  1   location             847 non-null    object
#  2   department           335 non-null    object
#  3   salary_range         223 non-null    object
#  4   company_profile      279 non-null    object
#  5   description          865 non-null    object
#  6   requirements         712 non-null    object
#  7   benefits             502 non-null    object
#  8   telecommuting        866 non-null    int64
#  9   has_company_logo     866 non-null    int64
#  10  has_questions        866 non-null    int64
#  11  employment_type      625 non-null    object
#  12  required_experience  431 non-null    object
#  13  required_education   415 non-null    object
#  14  industry             591 non-null    object
# ...

# %%
industry = fraudulent['industry'].value_counts()
industry.head(10)
# Out:
# Oil & Energy                           109
# Accounting                              57
# Hospital & Health Care                  51
# Marketing and Advertising               45
# Financial Services                      35
# Information Technology and Services     32
# Telecommunications                      26
# Real Estate                             24
# Consumer Services                       24
# Leisure, Travel & Tourism               21
# Name: industry, dtype: int64

# %%
#Top 10 Fraudulent Industries
plt.barh(['Oil & Energy', "Accounting", "Hospital & health Care", "Marketing and Advertising", "Financial Services", "Information Technology & Services", "Telecommunications", "Real Estate", "Consumer Services", "Leisure, Travel & Tourism"], [109, 57, 51, 45, 35, 32, 26, 24, 24, 21], color = ['blue', 'red', 'purple', 'black', 'pink', 'yellow', 'magenta', 'green', 'orange', 'violet'])
plt.title("Top 10 Fraudulent Industries")
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# # The industry with the highest number of fake job postings is the Oil & Energy Industry

# %% [markdown]
# ## From the info of the extracted fraudulent job postings, 275 industry entries were missing. From the general dataset, the mode of the industry was Information and Technology Services. After attempting to fill up the missing values with the mode, the result was tilted and unbalanced.
# ### So this is the analysis of the raw data which had 275 missing values for more accuracy.
